# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/felic/Desktop/파이썬/머신/폐암/survey lung cancer.csv')

# %%
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
'''
Gender: M(male), F(female)  
Age: Age of the patient (나이)
Smoking: YES=2 , NO=1. (흡연)
Yellow fingers: YES=2 , NO=1. (노란 손가락)
Anxiety: YES=2 , NO=1. (불안)
Peer_pressure: YES=2 , NO=1. (부담감)
Chronic Disease: YES=2 , NO=1. (만성질환)
Fatigue: YES=2 , NO=1. (피로)
Allergy: YES=2 , NO=1. (알레르기)
Wheezing: YES=2 , NO=1. (천식 호릅)
Alcohol: YES=2 , NO=1. (음주)
Coughing: YES=2 , NO=1. (기침)
Shortness of Breath: YES=2 , NO=1.   (숨가쁨)
Swallowing Difficulty: YES=2 , NO=1. (삼키기 어려움)
Chest pain: YES=2 , NO=1. (흉통)
Lung Cancer: YES , NO.  (폐암)
'''
# Out:
# '\nGender: M(male), F(female)  \nAge: Age of the patient (나이)\nSmoking: YES=2 , NO=1. (흡연)\nYellow fingers: YES=2 , NO=1. (노란 손가락)\nAnxiety: YES=2 , NO=1. (불안)\nPeer_pressure: YES=2 , NO=1. (부담감)\nChronic Disease: YES=2 , NO=1. (만성질환)\nFatigue: YES=2 , NO=1. (피로)\nAllergy: YES=2 , NO=1. (알레르기)\nWheezing: YES=2 , NO=1. (천식 호릅)\nAlcohol: YES=2 , NO=1. (음주)\nCoughing: YES=2 , NO=1. (기침)\nShortness of Breath: YES=2 , NO=1.   (숨가쁨)\nSwallowing Difficulty: YES=2 , NO=1. (삼키기 어려움)\nChest pain: YES=2 , NO=1. (흉통)\nLung Cancer: YES , NO.  (폐암)\n'

# %%
#EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('ticks')
_, axe = plt.subplots(figsize=(12,5))
sns.histplot(data = data, x = 'AGE', hue = 'LUNG_CANCER',kde=True )
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Count'>

# %%
palette = sns.color_palette("deep")

# %%
_, axe = plt.subplots(figsize=(5,5))
sns.set_palette('deep')
sns.boxplot(data = data, x='LUNG_CANCER',y='AGE')   #50대부터 암환자가 증가한다.
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='AGE'>

# %%
plt.figure(figsize=(10,6))
sns.set_palette('deep')
sns.countplot(data=data,x='LUNG_CANCER')
  #기침
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.set_palette
sns.countplot(data=data,x='COUGHING',hue='LUNG_CANCER')
plt.legend(["Has cancer", 'Does not have cancer'])  #기침

# %%
_, axe = plt.subplots(figsize=(10,6))
sns.set_palette
sns.countplot(data=data, x='GENDER', hue='LUNG_CANCER' )
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %%
X = ['GENDER','SMOKING','YELLOW_FINGERS', 'ANXIETY','PEER_PRESSURE', 'CHRONIC DISEASE', 
     'FATIGUE ', 'ALLERGY ', 'WHEEZING','ALCOHOL CONSUMING', 'COUGHING', 
     'SHORTNESS OF BREATH',  'SWALLOWING DIFFICULTY', 'CHEST PAIN']
_, axes = plt.subplots(5,3, figsize=(16, 24))
try:
    for i in range(5):
        for j in range(3):
            sns.set_palette
            sns.countplot(x = data[X[3 * i + j]] , ax = axes[i][j])
except IndexError:
    pass

#1 = no  2 = yes

# %%
'''
ANXIETE, PEER_PRESSURE, CHRONIC DISEASE 이 3개는 수치가 비슷하니까 암과 관련이 없어 보인다.
그래서 암환자와 아닌 사람을 나눠 그래프를 보자
'''

# %%
'''
암환자만 그래프 보기
'''
# Out:
# '\n암환자만 그래프 보기\n'

# %%
Cancer = data['LUNG_CANCER'] =='YES'
Cancer
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 304     True
# 305     True
# 306     True
# 307     True
# 308     True
# Name: LUNG_CANCER, Length: 309, dtype: bool

# %%
data.loc[Cancer]['LUNG_CANCER']
# Out:
# 0      YES
# 1      YES
# 5      YES
# 6      YES
# 7      YES
#       ...
# 304    YES
# 305    YES
# 306    YES
# 307    YES
# 308    YES
# Name: LUNG_CANCER, Length: 270, dtype: object

# %%
Cancer = data.loc[Cancer]
Cancer
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 5        F   75        1               2        1              1
# 6        M   52        2               1        1              1
# 7        F   51        2               2        2              2
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
X = ['GENDER','SMOKING','YELLOW_FINGERS', 'ANXIETY','PEER_PRESSURE', 'CHRONIC DISEASE', 
     'FATIGUE ', 'ALLERGY ', 'WHEEZING','ALCOHOL CONSUMING', 'COUGHING', 
     'SHORTNESS OF BREATH',  'SWALLOWING DIFFICULTY', 'CHEST PAIN']
_, axes = plt.subplots(5,3, figsize=(16,24))
try:
    for i in range(5):
        for j in range(3):
            sns.set_palette
            sns.countplot(x = Cancer[X[3 * i + j]] , ax = axes[i][j])
except IndexError:
    pass
#1 = no  2 = yes

# %%
'''
암 환자 그래프를 봤을때는 크게 차이가 없어 보인다. 암환자가 아닌 사람들의 그래프를 보자
'''

# %%
'''
암이 아닌사람 
'''
# Out:
# '\n암이 아닌사람 \n'

# %%
Cancer_No = data['LUNG_CANCER'] =='NO'
Cancer_No
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 304    False
# 305    False
# 306    False
# 307    False
# 308    False
# Name: LUNG_CANCER, Length: 309, dtype: bool

# %%
#data.loc[Cancer_No]['LUNG_CANCER']

# %%
data.loc[Cancer_No]['LUNG_CANCER']
Cancer_No = data.loc[Cancer_No]
#Cancer_No

# %%
X = ['GENDER','SMOKING','YELLOW_FINGERS', 'ANXIETY','PEER_PRESSURE', 'CHRONIC DISEASE', 
     'FATIGUE ', 'ALLERGY ', 'WHEEZING','ALCOHOL CONSUMING', 'COUGHING', 
     'SHORTNESS OF BREATH',  'SWALLOWING DIFFICULTY', 'CHEST PAIN']
_, axes = plt.subplots(5,3, figsize=(16,24))
try:
    for i in range(5):
        for j in range(3):
            sns.set_palette
            sns.countplot(x = Cancer_No[X[3 * i + j]] , ax = axes[i][j])
except IndexError:
    pass
#1 = no  2 = yes
#1 = no  2 = yes

# %%
'''
ANXIETE, PEER_PRESSURE, CHRONIC DISEASE 
'''
# Out:
# '\n여기서 알수 있는것은 적어도 Smoking, Fatigue는 암과 관련없어 보인다\n'

# %%
sns.set_style('ticks')
_, axes = plt.subplots(2,1, figsize=(12,10))
sns.set_palette
plt.subplot(2, 1, 1)
plt.title("cancer_no")
sns.histplot(data = Cancer_No, x = 'AGE',kde=True)
plt.subplot(2, 1, 2)
sns.histplot(data = Cancer, x = 'AGE',kde=True)
plt.title("cancer")
# Out:
# Text(0.5, 1.0, 'cancer')
